# %%
import json
path = '../output/data.json'
d = json.load(open(path))['result']

# %%
import pandas as pd
# Out:
# result    {'2': [1.0, 1.9999600000000002, 2.999880001600...
# Name: points, dtype: object
